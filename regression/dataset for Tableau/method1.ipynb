# %%
import os
import glob
import pandas as pd
os.chdir("/Users/Guobao/Dropbox/Bootcamp/Projects/3/NBA_players_salary/regression/dataset for Tableau/method1")

# %%
# use glob to match the pattern 'csv'
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
method1_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
method1_csv
# Out:
#     Year                   Name   Age    Salary%        PER       USG%  \
# 0   2012      Amar'e Stoudemire  29.0  34.368408  17.700000  25.400000
# 1   2010       Andrei Kirilenko  28.0  30.889081  18.200000  17.700000
# 2   2010            Kobe Bryant  31.0  42.991768  21.900000  32.300000
# 3   2015            Kobe Bryant  36.0  39.641640  17.600000  34.900000
# 4   2016       Chandler Parsons  27.0  31.595357  16.200000  20.500000
# 5   2015          Dwight Howard  29.0  35.454474  19.200000  23.300000
# 6   2011          Kevin Garnett  34.0  36.605065  20.600000  22.300000
# 7   2014             Chris Bosh  29.0  35.181922  19.000000  22.600000
# 8   2016             Al Horford  29.0  37.914429  19.400000  20.600000
# 9   2011            Kobe Bryant  32.0  43.491994  23.900000  35.100000
# 10  2010          Nick Collison  29.0  22.998267  13.100000  12.100000
# 11  2013          Dirk Nowitzki  34.0  39.145099  19.800000  24.200000
# ...

# %%
#export to csv
method1_csv.to_csv( "method1.csv", index=False, encoding='utf-8-sig')
