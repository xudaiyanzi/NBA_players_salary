# %%
import pandas as pd

# %%
DF = pd.read_csv('clusters_and_salary.csv', index_col = 0)
statsDF = pd.read_csv('Seasons_Stats.csv', index_col = 0)

# %%
DF.head()
# Out:
#    Year           Name    Salary%  Physical Cluster  Reg Performance Cluster  \
# 0  2010   Aaron Brooks   3.495133                 0                        3
# 1  2010       Acie Law   1.097492                 0                        1
# 2  2010  Al Harrington   9.991334                 1                        0
# 3  2010     Al Horford   9.436494                 1                        0
# 4  2010   Al Jefferson  22.530329                 1                        3
#
#    Adv Performance Cluster
# 0                        3
# 1                        2
# 2                        3
# 3                        2
# 4                        2

# %%
statsDF.head()
# Out:
#      Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%  ...    \
# 0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 52 columns]

# %%
statsDF = statsDF[['Year', 'Player', 'Pos', 'Tm']]

# %%
statsDF = statsDF.dropna()

# %%
statsDF['Year'] = statsDF['Year'].astype(int)

# %%
statsDF.head()
# Out:
#    Year           Player  Pos   Tm
# 0  1950  Curly Armstrong  G-F  FTW
# 1  1950     Cliff Barker   SG  INO
# 2  1950    Leo Barnhorst   SF  CHS
# 3  1950       Ed Bartels    F  TOT
# 4  1950       Ed Bartels    F  DNN

# %%
def yearFilter(row):
    if not row['Year']:
        return
    if row['Year'] < 2010:
        return 
    elif row['Year'] > 2016:
        return
    else:
        return int(row['Year'])
statsDF['Year'] = statsDF.apply(yearFilter, axis = 1)
statsDF = statsDF.dropna()
statsDF.head()
# Out:
#          Year             Player Pos   Tm
# 19922  2010.0      Arron Afflalo  SG  DEN
# 19923  2010.0      Alexis Ajinca   C  CHA
# 19924  2010.0  LaMarcus Aldridge  PF  POR
# 19925  2010.0      Joe Alexander  SF  CHI
# 19926  2010.0        Malik Allen  PF  DEN

# %%
statsDF['Pos'].value_counts()
# Out:
# SG       847
# PG       836
# PF       831
# SF       804
# C        789
# SG-PG     10
# PG-SG      8
# SF-PF      8
# PF-SF      8
# C-PF       7
# SG-SF      7
# SF-SG      6
# PF-C       5
# SG-PF      1
# Name: Pos, dtype: int64

# %%
statsDF = statsDF.rename({'Player' : 'Name'}, axis = 'columns')

# %%
DF = DF.merge(statsDF, on = ['Year', 'Name'], how = 'left')

# %%
DF.head(50)
# Out:
#     Year               Name    Salary%  Physical Cluster  \
# 0   2010       Aaron Brooks   3.495133                 0
# 1   2010           Acie Law   1.097492                 0
# 2   2010           Acie Law   1.097492                 0
# 3   2010           Acie Law   1.097492                 0
# 4   2010           Acie Law   1.097492                 0
# 5   2010      Al Harrington   9.991334                 1
# 6   2010         Al Horford   9.436494                 1
# 7   2010       Al Jefferson  22.530329                 1
# 8   2010        Al Thornton   0.365830                 1
# 9   2010        Al Thornton   0.365830                 1
# 10  2010        Al Thornton   0.365830                 1
# 11  2010         Alonzo Gee   1.111163                 0
# 12  2010  Amar'e Stoudemire  28.572983                 1
# 13  2010   Anderson Varejao  12.620135                 1
# 14  2010     Andray Blatche  10.232499                 1
# ...

# %%
testDF = DF.groupby(['Year', 'Name'])
testDF.count()
# Out:
#                           Salary%  Physical Cluster  Reg Performance Cluster  \
# Year Name
# 2010 Aaron Brooks               1                 1                        1
#      Acie Law                   4                 4                        4
#      Al Harrington              1                 1                        1
#      Al Horford                 1                 1                        1
#      Al Jefferson               1                 1                        1
#      Al Thornton                3                 3                        3
#      Alonzo Gee                 1                 1                        1
#      Amar'e Stoudemire          1                 1                        1
#      Anderson Varejao           1                 1                        1
#      Andray Blatche             1                 1                        1
#      Andre Iguodala             1                 1                        1
# ...

# %%
###### test without team
smallStatsDF = statsDF.drop('Tm', axis = 'columns')
DF = DF.merge(smallStatsDF, on = ['Year', 'Name'], how = 'left')
DF.head()
# Out:
#    Year          Name   Salary%  Physical Cluster  Reg Performance Cluster  \
# 0  2010  Aaron Brooks  3.495133                 0                        3
# 1  2010      Acie Law  1.097492                 0                        1
# 2  2010      Acie Law  1.097492                 0                        1
# 3  2010      Acie Law  1.097492                 0                        1
# 4  2010      Acie Law  1.097492                 0                        1
#
#    Adv Performance Cluster Pos
# 0                        3  PG
# 1                        2  PG
# 2                        2  PG
# 3                        2  PG
# 4                        2  PG

# %%
DF.to_csv('cluster_pos_tm.csv')
