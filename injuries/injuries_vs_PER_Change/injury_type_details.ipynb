# %%
# import Pandas
import pandas as pd

# %%
# read pysical data from 2010_2017
df_2 = pd.read_csv("injuries_parts_sort.csv")
df_2.count()
# Out:
# Year            9783
# Name            9783
# Team            9780
# Injury Part     9783
# Injury Class    9783
# Date            9783
# Notes           9783
# dtype: int64

# %%
df_2_2 = df_2[["Year","Name","Injury Part","Date"]]

# %%
knee = (df_2[df_2['Injury Part'] == "knee"])                  
ankle = (df_2[df_2['Injury Part'] == "ankle"]) 
back = (df_2[df_2['Injury Part'] == "back"])
foot = (df_2[df_2['Injury Part'] == "foot"])
rest = (df_2[df_2['Injury Part'] == "rest"])   
hamstring = (df_2[df_2['Injury Part'] == "hamstring"])
shoulder = (df_2[df_2['Injury Part'] == "shoulder"])
leg_bone = (df_2[df_2['Injury Part'] == "leg bone"])
abdominal = (df_2[df_2['Injury Part'] == "abdominal"])
infection = (df_2[df_2['Injury Part'] == "infection"])
illness = (df_2[df_2['Injury Part'] == "illness"])
hip = (df_2[df_2['Injury Part'] == "hip"])
calf = (df_2[df_2['Injury Part'] == "calf"])
head = (df_2[df_2['Injury Part'] == "head"])
finger = (df_2[df_2['Injury Part'] == "finger"])
hand = (df_2[df_2['Injury Part'] == "hand"])
wrist = (df_2[df_2['Injury Part'] == "wrist"])
arm = (df_2[df_2['Injury Part'] == "arm"])
tendon = (df_2[df_2['Injury Part'] == "tendon"])
other = (df_2[df_2['Injury Part'] == "other"])
face = (df_2[df_2['Injury Part'] == "face"])
toe = (df_2[df_2['Injury Part'] == "toe"])
chest_bone = (df_2[df_2['Injury Part'] == "chest bone"])
neck = (df_2[df_2['Injury Part'] == "neck"])
heel = (df_2[df_2['Injury Part'] == "heel"])
mouth = (df_2[df_2['Injury Part'] == "mouth"])
hernia = (df_2[df_2['Injury Part'] == "hernia"])
lung = (df_2[df_2['Injury Part'] == "lung"])
nerve_root_irritation = (df_2[df_2['Injury Part'] == "nerve root irritation"])
chest_muscle = (df_2[df_2['Injury Part'] == "chest muscle"])
gastrocnemius = (df_2[df_2['Injury Part'] == "gastrocnemius"])
heart = (df_2[df_2['Injury Part'] == "heart"])
soreness = (df_2[df_2['Injury Part'] == "soreness"])
blood = (df_2[df_2['Injury Part'] == "blood"])
other_muscle = (df_2[df_2['Injury Part'] == "other muscle"])
quadricap = (df_2[df_2['Injury Part'] == "quadricap"])
spinal_cord = (df_2[df_2['Injury Part'] == "spinal cord"])

# %%
knee_count = knee.groupby(['Year', 'Name','Date']).count()                 
ankle_count = ankle.groupby(['Year', 'Name','Date']).count() 
back_count = back.groupby(['Year', 'Name','Date']).count() 
foot_count = foot.groupby(['Year', 'Name','Date']).count() 
rest_count = rest.groupby(['Year', 'Name','Date']).count()  
hamstring_count = hamstring.groupby(['Year', 'Name','Date']).count() 
shoulder_count = shoulder.groupby(['Year', 'Name','Date']).count() 
leg_bone_count = leg_bone.groupby(['Year', 'Name','Date']).count() 
abdominal_count = abdominal.groupby(['Year', 'Name','Date']).count() 
infection_count = infection.groupby(['Year', 'Name','Date']).count() 
illness_count = illness.groupby(['Year', 'Name','Date']).count() 
hip_count = hip.groupby(['Year', 'Name','Date']).count() 
calf_count = calf.groupby(['Year', 'Name','Date']).count() 
head_count = head.groupby(['Year', 'Name','Date']).count() 
finger_count = finger.groupby(['Year', 'Name','Date']).count() 
hand_count = hand.groupby(['Year', 'Name','Date']).count() 
wrist_count = wrist.groupby(['Year', 'Name','Date']).count() 
arm_count = arm.groupby(['Year', 'Name','Date']).count() 
tendon_count = tendon.groupby(['Year', 'Name','Date']).count() 
other_count = other.groupby(['Year', 'Name','Date']).count() 
face_count = face.groupby(['Year', 'Name','Date']).count() 
toe_count = toe.groupby(['Year', 'Name','Date']).count() 
chest_bone_count = chest_bone.groupby(['Year', 'Name','Date']).count() 
neck_count = neck.groupby(['Year', 'Name','Date']).count() 
heel_count = heel.groupby(['Year', 'Name','Date']).count() 
mouth_count = mouth.groupby(['Year', 'Name','Date']).count() 
hernia_count = hernia.groupby(['Year', 'Name','Date']).count() 
lung_count = lung.groupby(['Year', 'Name','Date']).count() 
nerve_root_irritation_count = nerve_root_irritation.groupby(['Year', 'Name','Date']).count() 
chest_muscle_count = chest_muscle.groupby(['Year', 'Name','Date']).count() 
gastrocnemius_count = gastrocnemius.groupby(['Year', 'Name','Date']).count() 
heart_count = heart.groupby(['Year', 'Name','Date']).count() 
soreness_count = soreness.groupby(['Year', 'Name','Date']).count() 
blood_count = blood.groupby(['Year', 'Name','Date']).count() 
other_muscle_count = other_muscle.groupby(['Year', 'Name','Date']).count() 
quadricap_count = quadricap.groupby(['Year', 'Name','Date']).count() 
spinal_cord_count = spinal_cord.groupby(['Year', 'Name','Date']).count()

# %%
# reset index
knee_count = knee_count.reset_index(level=[0,1])
ankle_count = ankle_count.reset_index(level=[0,1])
back_count = back_count.reset_index(level=[0,1])
foot_count = foot_count.reset_index(level=[0,1])
rest_count = rest_count.reset_index(level=[0,1])  
hamstring_count = hamstring_count.reset_index(level=[0,1])
shoulder_count = shoulder_count.reset_index(level=[0,1])
leg_bone_count = leg_bone_count.reset_index(level=[0,1])
abdominal_count = abdominal_count.reset_index(level=[0,1])
infection_count = infection_count.reset_index(level=[0,1])
illness_count = illness_count.reset_index(level=[0,1])
hip_count = hip_count.reset_index(level=[0,1])
calf_count = calf_count.reset_index(level=[0,1])
head_count = head_count.reset_index(level=[0,1])
finger_count = finger_count.reset_index(level=[0,1])
hand_count = hand_count.reset_index(level=[0,1]) 
wrist_count = wrist_count.reset_index(level=[0,1]) 
arm_count = arm_count.reset_index(level=[0,1])
tendon_count = tendon_count.reset_index(level=[0,1])
other_count = other_count.reset_index(level=[0,1])
face_count = face_count.reset_index(level=[0,1])
toe_count = toe_count.reset_index(level=[0,1]) 
chest_bone_count = chest_bone_count.reset_index(level=[0,1])
neck_count = neck_count.reset_index(level=[0,1])
heel_count = heel_count.reset_index(level=[0,1])
mouth_count = mouth_count.reset_index(level=[0,1])
hernia_count = hernia_count.reset_index(level=[0,1])
lung_count = lung_count.reset_index(level=[0,1])
nerve_root_irritation_count = nerve_root_irritation_count.reset_index(level=[0,1])
chest_muscle_count = chest_muscle_count.reset_index(level=[0,1])
gastrocnemius_count = gastrocnemius_count.reset_index(level=[0,1])
heart_count = heart_count.reset_index(level=[0,1])
soreness_count = soreness_count.reset_index(level=[0,1])
blood_count = blood_count.reset_index(level=[0,1]) 
other_muscle_count = other_muscle_count.reset_index(level=[0,1]) 
quadricap_count = quadricap_count.reset_index(level=[0,1])
spinal_cord_count = spinal_cord_count.reset_index(level=[0,1])

# %%
spinal_cord_count
# Out:
#             Year             Name  Team  Injury Part  Injury Class  Notes
# Date
# 2011-02-06  2010  Marquis Daniels     1            1             1      1

# %%
#make a new dataframe to contain data
df_3 = df_2_2.groupby(['Year', 'Name',"Date"])
DF = df_3.count()


DF["knee"] = 0                  
DF["ankle"] = 0 
DF["back"] = 0 
DF["foot"] = 0 
DF["rest"] = 0   
DF["hamstring"] = 0       
DF["shoulder"] = 0          
DF["leg bone"] = 0           
DF["abdominal"] = 0  
DF["infection"] = 0  
DF["illness"] = 0 
DF["hip"] = 0
DF["calf"] = 0 
DF["head"] = 0 
DF["finger"] = 0
DF["hand"] = 0
DF["wrist"] = 0 
DF["arm"] = 0
DF["tendon"] = 0
DF["other"] = 0 
DF["face"] = 0
DF["toe"] = 0
DF["chest bone"] = 0
DF["neck"] = 0
DF["heel"] = 0
DF["mouth"] = 0
DF["hernia"] = 0
DF["lung"] = 0
DF["nerve root irritation"] = 0
DF["chest muscle"] = 0
DF["gastrocnemius"] = 0
DF["heart"] = 0
DF["soreness"] = 0
DF["blood"] = 0
DF["other muscle"] = 0
DF["quadricap"] = 0
DF["spinal cord"] = 0

# %%
DF.head()
# Out:
#                                Injury Part  knee  ankle  back  foot  rest  \
# Year Name          Date
# 2010 Acie Law      2011-04-07            1     0      0     0     0     0
#      Al Harrington 2010-10-09            1     0      0     0     0     0
#                    2011-03-19            1     0      0     0     0     0
#                    2011-04-11            1     0      0     0     0     0
#      Al Thornton   2011-02-09            1     0      0     0     0     0
#
#                                hamstring  shoulder  leg bone  abdominal  ...  \
# Year Name          Date                                                  ...
# 2010 Acie Law      2011-04-07          0         0         0          0  ...
#      Al Harrington 2010-10-09          0         0         0          0  ...
#                    2011-03-19          0         0         0          0  ...
#                    2011-04-11          0         0         0          0  ...
# ...

# %%
DF = DF.merge(knee_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['knee'], axis = 'columns')
DF = DF.rename({'Injury Part_x':'Injury Total', 'Injury Part_y' : 'knee'}, axis = 'columns')

# %%
DF = DF.merge(ankle_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['ankle'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'ankle'}, axis = 'columns')

# %%
DF = DF.merge(back_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['back'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'back'}, axis = 'columns')

# %%
DF = DF.merge(foot_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['foot'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'foot'}, axis = 'columns')

# %%
DF.head()
# Out:
#             Year           Name  Injury Total  rest  hamstring  shoulder  \
# Date
# 2011-04-07  2010       Acie Law             1     0          0         0
# 2010-10-09  2010  Al Harrington             1     0          0         0
# 2011-03-19  2010  Al Harrington             1     0          0         0
# 2011-04-11  2010  Al Harrington             1     0          0         0
# 2011-02-09  2010    Al Thornton             1     0          0         0
#
#             leg bone  abdominal  infection  illness  ...  heart  soreness  \
# Date                                                 ...
# 2011-04-07         0          0          0        0  ...      0         0
# 2010-10-09         0          0          0        0  ...      0         0
# 2011-03-19         0          0          0        0  ...      0         0
# 2011-04-11         0          0          0        0  ...      0         0
# 2011-02-09         0          0          0        0  ...      0         0
#
# ...

# %%
DF = DF.merge(rest_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['rest'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'rest'}, axis = 'columns')

DF = DF.merge(hamstring_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['hamstring'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'hamstring'}, axis = 'columns')

DF = DF.merge(shoulder_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['shoulder'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'shoulder'}, axis = 'columns')

DF = DF.merge(leg_bone_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['leg bone'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'leg bone'}, axis = 'columns')

DF = DF.merge(abdominal_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['abdominal'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'abdominal'}, axis = 'columns')

DF = DF.merge(infection_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['infection'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'infection'}, axis = 'columns')

DF = DF.merge(illness_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['illness'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'illness'}, axis = 'columns')

DF = DF.merge(hip_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['hip'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'hip'}, axis = 'columns')

DF = DF.merge(calf_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['calf'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'calf'}, axis = 'columns')

DF = DF.merge(head_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['head'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'head'}, axis = 'columns')

DF = DF.merge(finger_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['finger'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'finger'}, axis = 'columns')

DF = DF.merge(hand_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['hand'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'hand'}, axis = 'columns')

DF = DF.merge(wrist_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['wrist'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'wrist'}, axis = 'columns')

DF = DF.merge(arm_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['arm'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'arm'}, axis = 'columns')

DF = DF.merge(tendon_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['tendon'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'tendon'}, axis = 'columns')

DF = DF.merge(other_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['other'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'other'}, axis = 'columns')

DF = DF.merge(face_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['face'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'face'}, axis = 'columns')

DF = DF.merge(toe_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['toe'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'toe'}, axis = 'columns')

DF = DF.merge(chest_bone_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['chest bone'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'chest bone'}, axis = 'columns')

DF = DF.merge(neck_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['neck'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'neck'}, axis = 'columns')

DF = DF.merge(heel_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['heel'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'heel'}, axis = 'columns')

DF = DF.merge(mouth_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['mouth'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'mouth'}, axis = 'columns')

DF = DF.merge(hernia_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['hernia'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'hernia'}, axis = 'columns')

DF = DF.merge(lung_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['lung'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'lung'}, axis = 'columns')

DF = DF.merge(nerve_root_irritation_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['nerve root irritation'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'nerve root irritation'}, axis = 'columns')

DF = DF.merge(chest_muscle_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['chest muscle'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'chest muscle'}, axis = 'columns')

DF = DF.merge(gastrocnemius_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['gastrocnemius'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'gastrocnemius'}, axis = 'columns')

DF = DF.merge(heart_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['heart'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'heart'}, axis = 'columns')

DF = DF.merge(soreness_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['soreness'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'soreness'}, axis = 'columns')

DF = DF.merge(blood_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['blood'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'blood'}, axis = 'columns')

DF = DF.merge(other_muscle_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['other muscle'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'other muscle'}, axis = 'columns')

DF = DF.merge(quadricap_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['quadricap'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'quadricap'}, axis = 'columns')

DF = DF.merge(spinal_cord_count[['Year', 'Name', 'Injury Part']], how = 'left', on = ['Year', 'Name','Date'])
DF = DF.drop(['spinal cord'], axis = 'columns')
DF = DF.rename({'Injury Part' : 'spinal cord'}, axis = 'columns')

# %%
DF = DF.fillna(0)
DF.head(100)
# Out:
#             Year              Name  Injury Total  knee  ankle  back  foot  \
# Date
# 2011-04-07  2010          Acie Law             1   0.0    0.0   0.0   0.0
# 2010-10-09  2010     Al Harrington             1   0.0    0.0   0.0   1.0
# 2011-03-19  2010     Al Harrington             1   0.0    0.0   0.0   0.0
# 2011-04-11  2010     Al Harrington             1   0.0    0.0   0.0   0.0
# 2011-02-09  2010       Al Thornton             1   0.0    0.0   0.0   0.0
# 2011-02-08  2010     Alexis Ajinca             1   0.0    0.0   0.0   1.0
# 2011-02-11  2010     Alexis Ajinca             1   0.0    0.0   0.0   1.0
# 2011-03-09  2010     Alexis Ajinca             1   1.0    0.0   0.0   0.0
# 2011-03-11  2010     Alexis Ajinca             1   1.0    0.0   0.0   0.0
# 2011-03-25  2010      Amir Johnson             1   0.0    1.0   0.0   0.0
# 2011-04-06  2010      Amir Johnson             1   0.0    1.0   0.0   0.0
# 2011-04-10  2010      Amir Johnson             1   0.0    1.0   0.0   0.0
# ...

# %%
DF.to_csv('injury_clean_details.csv')
